# %% [markdown]
# # Visualizing Relationships and Distributions in Seaborn

# %% [markdown]
# ### Getting into the seaborn domain

# %%
# !pip install seaborn --upgrade
# Out:
# Requirement already up-to-date: seaborn in /Users/kamal/anaconda3/lib/python3.7/site-packages (0.9.0)
# ...

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.9.0'

# %% [markdown]
# ### What data do we work on?
# Ideally, data in a tabulated format - Pandas dataframes for instance
#
# #### We use the Pandas library for generating dataframes

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.1'

# %% [markdown]
# ###### Seaborn contain some sample datasets in order to perform the visualisation operations. In further course the stored data will be used but here the UFO POLLUTANTS DATASET  has been loaded and the stastical characteristics of the dataset is evaluated

# %%
pollution_data = pd.read_csv('/Users/kamal/Desktop/work/20_JupyterNotebooks/Data/UFOPOLLUTANTS.csv')

# %% [markdown]
#  File downloaded from https://www.kaggle.com/infof422henni/ufo-air-quality/home

# %%
pollution_data.head()
# Out:
#    State.Code                         city state  day  month  year  hour  \
# 0           4  kingman (desert&#44 out of)    az    7      7  2000    21
# 1           4               tacna (approx)    az    7      7  2000    21
# 2           4              apache junction    az    6      9  2001    21
# 3           4                       sedona    az    5      6  2005    21
# 4           4                       tucson    az    5     10  2007     2
#
#    NO2.Mean  NO2.1st.Max.Value  NO2.1st.Max.Hour  ...  O3.AQI  SO2.Mean  \
# 0  7.375000               15.0                 6  ...      45    1.0000
# 1  7.375000               15.0                 6  ...      45    1.0000
# 2  7.708333               19.0                 6  ...      31    0.1875
# 3  7.916667               17.0                 6  ...      41    3.0000
# 4  8.625000               20.0                 6  ...      34    0.0375
#
#    SO2.1st.Max.Value  SO2.1st.Max.Hour  SO2.AQI   CO.Mean  CO.1st.Max.Value  \
# ...

# %%
pollution_data.tail()
# Out:
#        State.Code     city       state  day  month  year  hour  NO2.Mean  \
# 63168           6  Capitan  California   30     12  2001     7  3.043478
# 63169           6  Capitan  California   31     12  2001     9  2.434783
# 63170           6  Capitan  California   31     12  2001    22  2.434783
# 63171           6  Capitan  California   31     12  2001    23  2.434783
# 63172           6  Capitan  California   31     12  2001    19  2.434783
#
#        NO2.1st.Max.Value  NO2.1st.Max.Hour  ...  O3.AQI  SO2.Mean  \
# 63168                6.0                 0  ...      25       0.0
# 63169                4.0                14  ...      24       0.0
# 63170                4.0                14  ...      24       0.0
# 63171                4.0                14  ...      24       0.0
# 63172                4.0                14  ...      24       0.0
#
#        SO2.1st.Max.Value  SO2.1st.Max.Hour  SO2.AQI   CO.Mean  \
# 63168                0.0                 5      NaN  0.254167
# ...

# %% [markdown]
# #### Check the size of the dataset

# %%
len(pollution_data.index)
# Out:
# 63173

# %% [markdown]
# #### Limit the size of the dataset
# As the dataset is too long we will take only top 1000 row for our statistical Visualisation

# %%
pollution_data = pollution_data.head(1000)

# %%
len(pollution_data.index)
# Out:
# 1000

# %%
pollution_data.describe()
# Out:
#         State.Code          day        month         year        hour  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     10.933000     9.963000     4.759000  2002.697000    14.02400
# std      13.365371     7.372651     3.471739     2.871835     7.92971
# min       4.000000     1.000000     1.000000  2000.000000     0.00000
# 25%       4.000000     5.000000     2.000000  2000.000000     6.00000
# 50%       6.000000     8.000000     3.000000  2002.000000    17.50000
# 75%       6.000000    12.000000     7.000000  2005.000000    21.00000
# max      51.000000    31.000000    12.000000  2008.000000    23.00000
#
#           NO2.Mean  NO2.1st.Max.Value  NO2.1st.Max.Hour     NO2.AQI  \
# count  1000.000000        1000.000000       1000.000000  1000.00000
# mean     22.794976          40.098100         13.381000    38.19600
# std      14.666838          22.723358          8.109353    21.93168
# ...

# %%
pollution_data.describe(include='all')
# Out:
#          State.Code     city state          day        month         year  \
# count   1000.000000     1000  1000  1000.000000  1000.000000  1000.000000
# unique          NaN      409    21          NaN          NaN          NaN
# top             NaN  Phoenix    ca          NaN          NaN          NaN
# freq            NaN      379   379          NaN          NaN          NaN
# mean      10.933000      NaN   NaN     9.963000     4.759000  2002.697000
# std       13.365371      NaN   NaN     7.372651     3.471739     2.871835
# min        4.000000      NaN   NaN     1.000000     1.000000  2000.000000
# 25%        4.000000      NaN   NaN     5.000000     2.000000  2000.000000
# 50%        6.000000      NaN   NaN     8.000000     3.000000  2002.000000
# 75%        6.000000      NaN   NaN    12.000000     7.000000  2005.000000
# max       51.000000      NaN   NaN    31.000000    12.000000  2008.000000
#
#               hour     NO2.Mean  NO2.1st.Max.Value  NO2.1st.Max.Hour  ...  \
# ...
