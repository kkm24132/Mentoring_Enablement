# %%
## Plotting horizontal and vertical bar graphs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/kamal/Desktop/work/20_JupyterNotebooks/Data/countries of the world.csv')

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.Population.plot(kind='bar',
                  title='Population By Country')

# %%
df.Population.plot(kind='barh',
                  title='Population By Country')

# %%
## Statistical information in a box plot

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
df1 = df

# %%
df1.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
## If you want to remove a column from the data frame

# df1 = df1.drop(["Region"],axis=1) CORRECT option
# del df1["Region"] CORRECT as well

# %%
# Check below
pd.Timestamp('01/01/2000') \
+ pd.Timedelta('2days 2hours 1minute 1second')
# Out:
# Timestamp('2000-01-03 02:01:01')

# %%
# Check below
string = pd.Series(['Ace', 'Fault', 'Error'])  
new_string = string.str.swapcase()
new_string
# Out:
# 0      aCE
# 1    fAULT
# 2    eRROR
# dtype: object

# %%
string = pd.Series(['1', '2', '3'])

# %%
pd.to_numeric(string)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
string.head()
# Out:
# 0    1
# 1    2
# 2    3
# dtype: object

# %%
df1.head(5)
# Out:
#            Country  Population  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# 0     Afghanistan     31056997          647500                       48,0
# 1         Albania      3581655           28748                      124,6
# 2         Algeria     32930091         2381740                       13,8
# 3  American Samoa        57794             199                      290,4
# 4         Andorra        71201             468                      152,1
#
#   Coastline (coast/area ratio) Net migration  \
# 0                         0,00         23,06
# 1                         1,26         -4,93
# 2                         0,04         -0,39
# 3                        58,29        -20,71
# 4                         0,00           6,6
#
#   Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# 0                             163,07               700.0         36,0
# 1                              21,52              4500.0         86,5
# ...

# %%
df1.apply('min',axis=1)
# Out:
# 0         700.0
# 1        4500.0
# 2        6000.0
# 3         199.0
# 4         468.0
#          ...
# 222       800.0
# 223    266000.0
# 224       800.0
# 225       800.0
# 226      1900.0
# Length: 227, dtype: float64

# %%
df1.apply('min',axis=0)
# Out:
# Country                         Afghanistan
# Population                              7026
# Area (sq. mi.)                             2
# Pop. Density (per sq. mi.)               0,0
# Coastline (coast/area ratio)            0,00
# GDP ($ per capita)                       500
# dtype: object

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000
